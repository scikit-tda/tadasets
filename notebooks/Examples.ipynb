# %% [markdown]
# # Show Shapes

# %%
import tadasets

# %%
t = tadasets.torus(n=2000, c=10, a=2)
tadasets.plot3d(t)

# %%
t = tadasets.sphere(n=1000, r=4)
tadasets.plot3d(t)

# %%
t = tadasets.swiss_roll(n=2000)
tadasets.plot3d(t)
